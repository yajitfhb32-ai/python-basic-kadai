# %%
# クラスの定義（例：class Product: ...... ）
class Human:
    # コンストラクタの定義
    def __init__(self, name, age):
        self.name=name
        self.age=age

human=Human("侍太郎",36)

print(human.name)
print(human.age)
# Out:
# 侍太郎
# 36
